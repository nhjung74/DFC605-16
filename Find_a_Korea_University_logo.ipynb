# %% [markdown]
# <a href="https://colab.research.google.com/github/jundeyo/DFC605-16/blob/master/Find_a_Korea_University_logo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-705de84a-5f3b-41c2-b01f-bdace6aa814b" name="files[]" multiple disabled />
#      <output id="result-705de84a-5f3b-41c2-b01f-bdace6aa814b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving base.PNG to base.PNG
# Saving base-korea.PNG to base-korea.PNG
# Saving base-korea-label.PNG to base-korea-label.PNG
# Saving base-label.PNG to base-label.PNG

# %%
# !ls
# Out:
# base-korea-label.PNG  base-korea.PNG  base-label.PNG  base.PNG	sample_data

# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

filename = 'base'

img = Image.open( filename + '.PNG' )
data = np.array( img, dtype='uint8' )

np.save( filename + '.npy', data)

# visually testing our output
img_array = np.load(filename + '.npy')
plt.imshow(img_array)

# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

filename = 'base-label'

img = Image.open( filename + '.PNG' )
data = np.array( img, dtype='uint8' )

np.save( filename + '.npy', data)

# visually testing our output
img_array = np.load(filename + '.npy')
plt.imshow(img_array)

# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

filename = 'base-korea'

img = Image.open( filename + '.PNG' )
data = np.array( img, dtype='uint8' )

np.save( filename + '.npy', data)

# visually testing our output
img_array = np.load(filename + '.npy')
plt.imshow(img_array)

# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

filename = 'base-korea-label'

img = Image.open( filename + '.PNG' )
data = np.array( img, dtype='uint8' )

np.save( filename + '.npy', data)

# visually testing our output
img_array = np.load(filename + '.npy')
plt.imshow(img_array)

# %%
# !ls
# Out:
# base-korea-label.npy  base-korea.npy  base-label.npy  base.npy	sample_data
# base-korea-label.PNG  base-korea.PNG  base-label.PNG  base.PNG
